# %%
import pandas as pd
import json

# %%
df = pd.read_csv("developer_ai_learning_raw.csv")

# %%
df.shape
# Out:
# (49191, 11)

# %%
df.columns
# Out:
# Index(['ResponseId', 'Age', 'YearsCode', 'DevType', 'LearnCodeChoose',
#        'LearnCode', 'LearnCodeAI', 'AILearnHow', 'AISelect', 'AIAcc',
#        'AISent'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ResponseId       49191 non-null  int64
#  1   Age              49191 non-null  object
#  2   YearsCode        43042 non-null  float64
#  3   DevType          43680 non-null  object
#  4   LearnCodeChoose  46858 non-null  object
#  5   LearnCode        33556 non-null  object
#  6   LearnCodeAI      45201 non-null  object
#  7   AILearnHow       28257 non-null  object
#  8   AISelect         33720 non-null  object
#  9   AIAcc            33297 non-null  object
#  10  AISent           33467 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.1+ MB
# None

# %%
df['AILearnHow'].str.contains(";").sum()
# Out:
# 20929

# %%
df['DevType'].value_counts().sort_values(ascending=False)
# Out:
# DevType
# Developer, full-stack                            12351
# Developer, back-end                               6453
# Student                                           3008
# Architect, software or solutions                  2684
# Developer, front-end                              1974
# Developer, desktop or enterprise applications     1919
# Other (please specify):                           1825
# Developer, mobile                                 1391
# Developer, embedded applications or devices       1274
# Academic researcher                               1131
# Engineering manager                               1068
# DevOps engineer or professional                   1053
# Data engineer                                      770
# AI/ML engineer                                     677
# Data scientist                                     574
# Senior executive (C-suite, VP, etc.)               528
# System administrator                               480
# Retired                                            458
# Developer, game or graphics                        451
# Cloud infrastructure engineer                      441
# Founder, technology or otherwise                   431
# Cybersecurity or InfoSec professional              370
# Data or business analyst                           351
# Developer, QA or test                              343
# Project manager                                    302
# Applied scientist                                  297
# Support engineer or analyst                        251
# Developer, AI apps or physical AI                  236
# Product manager                                    205
# Database administrator or engineer                 175
# UX, Research Ops or UI design professional         115
# Financial analyst or engineer                       94
# Name: count, dtype: int64

# %%
df.head(50)
# Out:
#     ResponseId                Age  YearsCode  \
# 0            1    25-34 years old         14
# 1            2    25-34 years old         10
# 2            3    35-44 years old         12
# 3            4    35-44 years old          5
# 4            5    35-44 years old         22
# 5            6    45-54 years old         20
# 6            7    25-34 years old         13
# 7            8    35-44 years old         30
# 8            9    25-34 years old         15
# 9           10    25-34 years old         10
# 10          11    25-34 years old          9
# 11          12    18-24 years old          5
# 12          13    35-44 years old         10
# 13          14    25-34 years old          6
# 14          15    35-44 years old       <NA>
# 15          16    18-24 years old          3
# 16          17  65 years or older         40
# 17          18    25-34 years old          8
# 18          19    35-44 years old         20
# 19          20    25-34 years old          6
# 20          21    55-64 years old         45
# 21          22    45-54 years old         35
# 22          23    25-34 years old         11
# 23          24    18-24 years old          7
# 24          25  65 years or older         47
# 25          26    55-64 years old         41
# 26          27    45-54 years old         30
# 27          28    45-54 years old         36
# 28          29    35-44 years old         13
# 29          30    35-44 years old         15
# 30          31    35-44 years old         15
# 31          32    35-44 years old         23
# 32          33    45-54 years old         29
# 33          34    45-54 years old         26
# 34          35    35-44 years old         25
# 35          36    25-34 years old         10
# 36          37    25-34 years old         15
# 37          38    35-44 years old         25
# 38          39    45-54 years old         25
# 39          40    45-54 years old          8
# 40          41    45-54 years old         38
# 41          42    45-54 years old         25
# 42          43    35-44 years old         35
# 43          44    25-34 years old         14
# 44          45    25-34 years old          6
# 45          46    45-54 years old         23
# 46          47    35-44 years old       <NA>
# 47          48    25-34 years old          9
# 48          49    35-44 years old         21
# 49          50    25-34 years old         12
#
#                                         DevType  \
# 0                             Developer, mobile
# 1                           Developer, back-end
# 2                          Developer, front-end
# 3                           Developer, back-end
# 4                           Engineering manager
# 5                           Developer, back-end
# 6                         Developer, full-stack
# 7              Architect, software or solutions
# 8                                 Data engineer
# 9                             Developer, mobile
# 10                          Developer, back-end
# 11                          Developer, back-end
# 12                         Developer, front-end
# 13                        Developer, full-stack
# 14             Architect, software or solutions
# 15                            Developer, mobile
# 16                Financial analyst or engineer
# 17                        Developer, full-stack
# 18                          Developer, back-end
# 19                          Academic researcher
# 20                          Academic researcher
# 21                          Academic researcher
# 22                        Developer, full-stack
# 23  Developer, embedded applications or devices
# 24                          Developer, back-end
# 25                        Developer, full-stack
# 26                        Developer, full-stack
# 27                        Developer, full-stack
# 28                        Developer, full-stack
# 29                            Developer, mobile
# 30        Cybersecurity or InfoSec professional
# 31                        Developer, full-stack
# 32                        Developer, full-stack
# 33                                Data engineer
# 34                        Developer, full-stack
# 35                          Developer, back-end
# 36                          Developer, back-end
# 37                        Developer, full-stack
# 38                        Developer, full-stack
# 39                        Developer, full-stack
# 40                        Developer, full-stack
# 41                         Developer, front-end
# 42                            Developer, mobile
# 43                  Developer, game or graphics
# 44                          Developer, back-end
# 45                               AI/ML engineer
# 46  Developer, embedded applications or devices
# 47                          Developer, back-end
# 48         Senior executive (C-suite, VP, etc.)
# 49                          Academic researcher
#
#                                       LearnCodeChoose LearnCode  \
# 0   Yes, I am not new to coding but am learning ne...      None
# 1   Yes, I am not new to coding but am learning ne...      None
# 2   Yes, I am not new to coding but am learning ne...      None
# 3   Yes, I am not new to coding but am learning ne...      None
# 4   No, I am not new to coding and did not learn n...      None
# 5   Yes, I am not new to coding but am learning ne...      None
# 6   Yes, I am not new to coding but am learning ne...      None
# 7   Yes, I am not new to coding but am learning ne...      None
# 8   Yes, I am not new to coding but am learning ne...      None
# 9   Yes, I am not new to coding but am learning ne...      None
# 10  No, I am not new to coding and did not learn n...      None
# 11  No, I am not new to coding and did not learn n...      None
# 12  Yes, I am not new to coding but am learning ne...      None
# 13  Yes, I am not new to coding but am learning ne...      None
# 14  No, I am not new to coding and did not learn n...      None
# 15     Yes, I am new to coding or currently a student      None
# 16  No, I am not new to coding and did not learn n...      None
# 17  Yes, I am not new to coding but am learning ne...      None
# 18  Yes, I am not new to coding but am learning ne...      None
# 19  Yes, I am not new to coding but am learning ne...      None
# 20  Yes, I am not new to coding but am learning ne...      None
# 21  Yes, I am not new to coding but am learning ne...      None
# 22  Yes, I am not new to coding but am learning ne...      None
# 23  Yes, I am not new to coding but am learning ne...      None
# 24  No, I am not new to coding and did not learn n...      None
# 25  Yes, I am not new to coding but am learning ne...      None
# 26  Yes, I am not new to coding but am learning ne...      None
# 27  No, I am not new to coding and did not learn n...      None
# 28  Yes, I am not new to coding but am learning ne...      None
# 29  Yes, I am not new to coding but am learning ne...      None
# 30  No, I am not new to coding and did not learn n...      None
# 31  No, I am not new to coding and did not learn n...      None
# 32  No, I am not new to coding and did not learn n...      None
# 33  Yes, I am not new to coding but am learning ne...      None
# 34  Yes, I am not new to coding but am learning ne...      None
# 35  Yes, I am not new to coding but am learning ne...      None
# 36  No, I am not new to coding and did not learn n...      None
# 37  No, I am not new to coding and did not learn n...      None
# 38  No, I am not new to coding and did not learn n...      None
# 39  No, I am not new to coding and did not learn n...      None
# 40  No, I am not new to coding and did not learn n...      None
# 41  Yes, I am not new to coding but am learning ne...      None
# 42  Yes, I am not new to coding but am learning ne...      None
# 43  No, I am not new to coding and did not learn n...      None
# 44  No, I am not new to coding and did not learn n...      None
# 45  No, I am not new to coding and did not learn n...      None
# 46  Yes, I am not new to coding but am learning ne...      None
# 47  Yes, I am not new to coding but am learning ne...      None
# 48  Yes, I am not new to coding but am learning ne...      None
# 49  Yes, I am not new to coding but am learning ne...      None
#
#                                           LearnCodeAI  \
# 0   Yes, I learned how to use AI-enabled tools for...
# 1   Yes, I learned how to use AI-enabled tools for...
# 2   Yes, I learned how to use AI-enabled tools for...
# 3   Yes, I learned how to use AI-enabled tools for...
# 4   Yes, I learned how to use AI-enabled tools for...
# 5   Yes, I learned how to use AI-enabled tools req...
# 6   Yes, I learned how to use AI-enabled tools for...
# 7   Yes, I learned how to use AI-enabled tools for...
# 8   Yes, I learned how to use AI-enabled tools for...
# 9   No, I learned something that was not related t...
# 10  Yes, I learned how to use AI-enabled tools for...
# 11  Yes, I learned how to use AI-enabled tools for...
# 12  No, I learned something that was not related t...
# 13  Yes, I learned how to use AI-enabled tools req...
# 14  No, I learned something that was not related t...
# 15  No, I learned something that was not related t...
# 16  No, I didn't spend time learning in the past year
# 17  Yes, I learned how to use AI-enabled tools for...
# 18  No, I didn't spend time learning in the past year
# 19  Yes, I learned how to use AI-enabled tools for...
# 20  No, I learned something that was not related t...
# 21  No, I didn't spend time learning in the past year
# 22  Yes, I learned how to use AI-enabled tools req...
# 23  No, I learned something that was not related t...
# 24  No, I learned something that was not related t...
# 25  Yes, I learned how to use AI-enabled tools for...
# 26  Yes, I learned how to use AI-enabled tools for...
# 27  Yes, I learned how to use AI-enabled tools for...
# 28  Yes, I learned how to use AI-enabled tools req...
# 29  Yes, I learned how to use AI-enabled tools req...
# 30  Yes, I learned how to use AI-enabled tools for...
# 31  No, I didn't spend time learning in the past year
# 32  No, I didn't spend time learning in the past year
# 33  No, I didn't spend time learning in the past year
# 34  Yes, I learned how to use AI-enabled tools for...
# 35  Yes, I learned how to use AI-enabled tools for...
# 36  Yes, I learned how to use AI-enabled tools for...
# 37  No, I didn't spend time learning in the past year
# 38  Yes, I learned how to use AI-enabled tools for...
# 39  Yes, I learned how to use AI-enabled tools for...
# 40  Yes, I learned how to use AI-enabled tools for...
# 41  Yes, I learned how to use AI-enabled tools req...
# 42  Yes, I learned how to use AI-enabled tools req...
# 43  Yes, I learned how to use AI-enabled tools for...
# 44  Yes, I learned how to use AI-enabled tools for...
# 45  No, I learned something that was not related t...
# 46  Yes, I learned how to use AI-enabled tools for...
# 47  Yes, I learned how to use AI-enabled tools for...
# 48  Yes, I learned how to use AI-enabled tools for...
# 49  Yes, I learned how to use AI-enabled tools for...
#
#                                            AILearnHow  \
# 0               [AI CodeGen tools or AI-enabled apps]
# 1               [AI CodeGen tools or AI-enabled apps]
# 2   [AI CodeGen tools or AI-enabled apps, Technica...
# 3   [AI CodeGen tools or AI-enabled apps, Videos (...
# 4   [Technical documentation (is generated for/by ...
# 5   [Technical documentation (is generated for/by ...
# 6   [AI CodeGen tools or AI-enabled apps, Videos (...
# 7   [AI CodeGen tools or AI-enabled apps, Blogs or...
# 8   [Technical documentation (is generated for/by ...
# 9                                                None
# 10  [AI CodeGen tools or AI-enabled apps, Technica...
# 11  [Videos (not associated with specific online c...
# 12                                               None
# 13  [AI CodeGen tools or AI-enabled apps, Other on...
# 14                                               None
# 15                                               None
# 16                                               None
# 17  [Videos (not associated with specific online c...
# 18                                               None
# 19  [AI CodeGen tools or AI-enabled apps, Videos (...
# 20                                               None
# 21                                               None
# 22                 [Colleague or on-the-job training]
# 23                                               None
# 24                                               None
# 25  [AI CodeGen tools or AI-enabled apps, Blogs or...
# 26  [Technical documentation (is generated for/by ...
# 27                                               None
# 28  [Technical documentation (is generated for/by ...
# 29  [AI CodeGen tools or AI-enabled apps, Technica...
# 30  [Technical documentation (is generated for/by ...
# 31                                               None
# 32                                               None
# 33                                               None
# 34  [Videos (not associated with specific online c...
# 35                 [Colleague or on-the-job training]
# 36  [Technical documentation (is generated for/by ...
# 37                                               None
# 38              [AI CodeGen tools or AI-enabled apps]
# 39  [AI CodeGen tools or AI-enabled apps, Colleagu...
# 40  [Other online resources (e.g. standard search,...
# 41  [Colleague or on-the-job training, Online Cour...
# 42  [AI CodeGen tools or AI-enabled apps, Technica...
# 43                       [Games or coding challenges]
# 44  [Other online resources (e.g. standard search,...
# 45                                               None
# 46  [AI CodeGen tools or AI-enabled apps, Technica...
# 47  [Technical documentation (is generated for/by ...
# 48  [Technical documentation (is generated for/by ...
# 49  [AI CodeGen tools or AI-enabled apps, Technica...
#
#                                        AISelect                       AIAcc  \
# 0   Yes, I use AI tools monthly or infrequently  Neither trust nor distrust
# 1                    Yes, I use AI tools weekly  Neither trust nor distrust
# 2                     Yes, I use AI tools daily              Somewhat trust
# 3                    Yes, I use AI tools weekly              Somewhat trust
# 4                    Yes, I use AI tools weekly  Neither trust nor distrust
# 5                     Yes, I use AI tools daily           Somewhat distrust
# 6                     Yes, I use AI tools daily              Somewhat trust
# 7                     Yes, I use AI tools daily              Somewhat trust
# 8   Yes, I use AI tools monthly or infrequently  Neither trust nor distrust
# 9                       No, and I don't plan to             Highly distrust
# 10                    Yes, I use AI tools daily           Somewhat distrust
# 11                    Yes, I use AI tools daily  Neither trust nor distrust
# 12  Yes, I use AI tools monthly or infrequently           Somewhat distrust
# 13                                         None                        None
# 14                    Yes, I use AI tools daily              Somewhat trust
# 15                    Yes, I use AI tools daily                Highly trust
# 16                      No, and I don't plan to             Highly distrust
# 17                    Yes, I use AI tools daily  Neither trust nor distrust
# 18                      No, and I don't plan to             Highly distrust
# 19                    Yes, I use AI tools daily  Neither trust nor distrust
# 20                      No, and I don't plan to             Highly distrust
# 21                      No, and I don't plan to             Highly distrust
# 22  Yes, I use AI tools monthly or infrequently           Somewhat distrust
# 23                      No, and I don't plan to           Somewhat distrust
# 24                      No, and I don't plan to             Highly distrust
# 25                    Yes, I use AI tools daily  Neither trust nor distrust
# 26                    Yes, I use AI tools daily              Somewhat trust
# 27                    Yes, I use AI tools daily  Neither trust nor distrust
# 28                   Yes, I use AI tools weekly              Somewhat trust
# 29                    Yes, I use AI tools daily           Somewhat distrust
# 30  Yes, I use AI tools monthly or infrequently  Neither trust nor distrust
# 31                      No, and I don't plan to             Highly distrust
# 32                      No, and I don't plan to              Somewhat trust
# 33                      No, and I don't plan to  Neither trust nor distrust
# 34                    Yes, I use AI tools daily  Neither trust nor distrust
# 35                    Yes, I use AI tools daily              Somewhat trust
# 36                    Yes, I use AI tools daily              Somewhat trust
# 37                      No, and I don't plan to             Highly distrust
# 38                    Yes, I use AI tools daily              Somewhat trust
# 39  Yes, I use AI tools monthly or infrequently             Highly distrust
# 40                    Yes, I use AI tools daily              Somewhat trust
# 41                    Yes, I use AI tools daily           Somewhat distrust
# 42                    Yes, I use AI tools daily              Somewhat trust
# 43  Yes, I use AI tools monthly or infrequently           Somewhat distrust
# 44                      No, and I don't plan to           Somewhat distrust
# 45                      No, and I don't plan to             Highly distrust
# 46                                         None                        None
# 47  Yes, I use AI tools monthly or infrequently  Neither trust nor distrust
# 48  Yes, I use AI tools monthly or infrequently             Highly distrust
# 49                    Yes, I use AI tools daily  Neither trust nor distrust
#
#               AISent
# 0        Indifferent
# 1        Indifferent
# 2          Favorable
# 3          Favorable
# 4          Favorable
# 5        Indifferent
# 6          Favorable
# 7     Very favorable
# 8        Indifferent
# 9        Unfavorable
# 10    Very favorable
# 11    Very favorable
# 12       Unfavorable
# 13              None
# 14         Favorable
# 15         Favorable
# 16  Very unfavorable
# 17       Unfavorable
# 18  Very unfavorable
# 19    Very favorable
# 20       Unfavorable
# 21  Very unfavorable
# 22       Unfavorable
# 23  Very unfavorable
# 24  Very unfavorable
# 25         Favorable
# 26         Favorable
# 27       Indifferent
# 28         Favorable
# 29         Favorable
# 30       Indifferent
# 31  Very unfavorable
# 32         Favorable
# 33       Indifferent
# 34    Very favorable
# 35    Very favorable
# 36         Favorable
# 37  Very unfavorable
# 38         Favorable
# 39       Unfavorable
# 40         Favorable
# 41         Favorable
# 42         Favorable
# 43       Unfavorable
# 44       Indifferent
# 45  Very unfavorable
# 46              None
# 47       Indifferent
# 48       Unfavorable
# 49         Favorable

# %%
df['YearsCode'].describe()
# Out:
# count    43042.000000
# mean        16.570861
# std         11.787610
# min          1.000000
# 25%          8.000000
# 50%         14.000000
# 75%         24.000000
# max        100.000000
# Name: YearsCode, dtype: float64

# %%
df[df['YearsCode'] > 80].head()
# Out:
#        ResponseId                Age  YearsCode  \
# 4933         4934    45-54 years old      100.0
# 6064         6065  Prefer not to say       99.0
# 6989         6990    25-34 years old      100.0
# 7881         7882    25-34 years old      100.0
# 11064       11065    25-34 years old      100.0
#
#                                 DevType  \
# 4933            Other (please specify):
# 6064   Architect, software or solutions
# 6989           Data or business analyst
# 7881        Support engineer or analyst
# 11064              System administrator
#
#                                          LearnCodeChoose  \
# 4933      Yes, I am new to coding or currently a student
# 6064   No, I am not new to coding and did not learn n...
# 6989      Yes, I am new to coding or currently a student
# 7881      Yes, I am new to coding or currently a student
# 11064     Yes, I am new to coding or currently a student
#
#                                                LearnCode  \
# 4933                             Other (please specify):
# 6064                                                 NaN
# 6989                          Games or coding challenges
# 7881                 AI CodeGen tools or AI-enabled apps
# 11064  Online Courses or Certification (includes all ...
#
#                                              LearnCodeAI  \
# 4933   No, I didn't spend time learning in the past year
# 6064   No, I didn't spend time learning in the past year
# 6989   Yes, I learned how to use AI-enabled tools req...
# 7881   Yes, I learned how to use AI-enabled tools for...
# 11064  Yes, I learned how to use AI-enabled tools for...
#
#                                               AILearnHow  \
# 4933                                                 NaN
# 6064                                                 NaN
# 6989   Other online resources (e.g. standard search, ...
# 7881                 AI CodeGen tools or AI-enabled apps
# 11064  AI CodeGen tools or AI-enabled apps;Technical ...
#
#                                           AISelect            AIAcc  \
# 4933                       No, and I don't plan to              NaN
# 6064                       No, and I don't plan to  Highly distrust
# 6989                     Yes, I use AI tools daily     Highly trust
# 7881                                           NaN              NaN
# 11064  Yes, I use AI tools monthly or infrequently     Highly trust
#
#                  AISent
# 4933                NaN
# 6064   Very unfavorable
# 6989     Very favorable
# 7881                NaN
# 11064               NaN

# %%
df['ResponseId'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['ResponseId'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['YearsCode'].isna().sum()
# Out:
# np.int64(6149)

# %%
df['YearsCode'] = pd.to_numeric(df['YearsCode'], errors='coerce').astype('Int64')

# %%
df['AILearnHow'].head(5)
# Out:
# 0                  AI CodeGen tools or AI-enabled apps
# 1                  AI CodeGen tools or AI-enabled apps
# 2    AI CodeGen tools or AI-enabled apps;Technical ...
# 3    AI CodeGen tools or AI-enabled apps;Videos (no...
# 4    Technical documentation (is generated for/by t...
# Name: AILearnHow, dtype: object

# %%
df['AILearnHow'] = df['AILearnHow'].apply(lambda x: x.split(";") if isinstance(x, str) else None)

# %%
df['LearnCode'] = df['LearnCode'].apply(lambda x: x.split(";") if isinstance(x, str) else None)

# %%
def clean_text_field(val):
    if val is None:
        return None
    if isinstance(val, (list, tuple)):
        items = [str(x).strip() for x in val if x is not None and str(x).strip().lower() not in ["nan", ""]]
        return items if items else None

    try:
        if pd.isna(val):
            return None
    except (ValueError, TypeError):
        pass

    s = str(val).strip()
    if s.lower() in ["nan", ""]:
        return None
    return s

passthrough_and_cats = ['AISelect', 'AIAcc', 'AISent', 'DevType', 'LearnCodeChoose', 'LearnCodeAI', 'Age']
for col in passthrough_and_cats:
    if col in df.columns:
        df[col] = df[col].apply(clean_text_field)

for col in ['LearnCode', 'AILearnHow']:
    if col in df.columns:
        def process_multi_select(val):
            cleaned = clean_text_field(val)
            if cleaned is None:
                return None
            if isinstance(cleaned, list):
                return cleaned
            return [item.strip() for item in str(cleaned).split(';') if item.strip()]

        df[col] = df[col].apply(process_multi_select)

with open("your_cleaned.jsonl", "w", encoding="utf-8") as f:
    for _, row in df.iterrows():
        record = {
            "ResponseId": int(row["ResponseId"]),
            "Age": row["Age"],
            "YearsCode": int(row["YearsCode"]) if row["YearsCode"] is not None and pd.notna(row["YearsCode"]) else None,
            "DevType": row["DevType"],
            "LearnCodeChoose": row["LearnCodeChoose"],
            "LearnCode": row["LearnCode"],
            "LearnCodeAI": row["LearnCodeAI"],
            "AILearnHow": row["AILearnHow"],
            "AISelect": row["AISelect"],
            "AIAcc": row["AIAcc"],
            "AISent": row["AISent"],
        }
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

# %%
import os

# %%
records = []
with open("your_cleaned.jsonl", "r") as f:
    for line in f:
        records.append(json.loads(line))

df = pd.DataFrame(records)

# %%
TECH_DOC = "Technical documentation (is generated for/by the tool or system)"
AI_CODEGEN = "AI CodeGen tools or AI-enabled apps"
STACK_OVERFLOW = "Stack Overflow or Stack Exchange"

# %%
def experience_level(years_code):
    if pd.isna(years_code):
        return "Unknown"
    if years_code <= 2:
        return "Beginner"
    if years_code <= 5:
        return "Early Career"
    if years_code <= 10:
        return "Experienced"
    return "Highly Experienced"

# %%
def has_option(options, target):
    if options is None:
        return False
    return target in options

# %%
has_option(["Books", "Stack Overflow"], "Stack Overflow")
# Out:
# True

# %%
df['experienceLevel'] = df['YearsCode'].apply(experience_level)

# %%
df['usesDocumentation'] = df['LearnCode'].apply(lambda x: has_option(x, TECH_DOC))
df['usesAIForLearning'] = df['LearnCode'].apply(lambda x: has_option(x, AI_CODEGEN))
df['usesStackOverflow'] = df['LearnCode'].apply(lambda x: has_option(x, STACK_OVERFLOW))

# %%
df = df.rename(columns={
    'ResponseId': 'responseId',
    'Age': 'age',
    'YearsCode': 'yearsCode',
    'DevType': 'devType',
    'LearnCodeChoose': 'learnCodeChoose',
    'LearnCode': 'learningMethods',
    'LearnCodeAI': 'learnCodeAI',
    'AILearnHow': 'aiLearningMethods',
    'AISelect': 'aiUsage',
    'AIAcc': 'aiTrust',
    'AISent': 'aiSentiment',
})

# %%
df.columns
# Out:
# Index(['responseId', 'age', 'yearsCode', 'devType', 'learnCodeChoose',
#        'learningMethods', 'learnCodeAI', 'aiLearningMethods', 'aiUsage',
#        'aiTrust', 'aiSentiment', 'experienceLevel', 'usesDocumentation',
#        'usesAIForLearning', 'usesStackOverflow'],
#       dtype='object')

# %%
with open("your_processed.jsonl", "w") as f:
    for _, row in df.iterrows():
        record = row.to_dict()

        # Convert NaN to None (skip lists)
        for key, value in record.items():
            if not isinstance(value, list) and pd.isna(value):
                record[key] = None

        f.write(json.dumps(record) + "\n")
